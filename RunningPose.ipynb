# %% [markdown]
# <a href="https://colab.research.google.com/github/Huni1i1/Running-Posture-Correction-AI/blob/main/RunningPose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running Posture Correction AI

# %% [markdown]
# # Environment Setup

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# !nvidia-smi
# Out:
# Mounted at /content/drive

# %%
# Install Detectron2
# %cd /content/
# !git clone https://github.com/facebookresearch/detectron2
# %cd /content/detectron2
# !pip install -r requirements.txt
# !python setup.py install
# !pip install git+https://github.com/facebookresearch/fvcore.git
# Out:
# /content
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15777, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 15777 (delta 7), reused 21 (delta 4), pack-reused 15743 (from 1)
# Receiving objects: 100% (15777/15777), 6.36 MiB | 16.20 MiB/s, done.
# Resolving deltas: 100% (11499/11499), done.
# /content/detectron2
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
# ...

# %%
# Clone RunningPose
# !git clone https://github.com/TIFX04-22-10/runningpose
# Out:
# Cloning into 'runningpose'...
# remote: Enumerating objects: 1441, done.
# remote: Counting objects: 100% (255/255), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 1441 (delta 157), reused 238 (delta 144), pack-reused 1186 (from 1)
# Receiving objects: 100% (1441/1441), 393.85 MiB | 31.71 MiB/s, done.
# Resolving deltas: 100% (755/755), done.
# /content/runningpose

# %%
# Download pre-trainde model
# !gdown https://drive.google.com/uc?id=1bEPUXcjW7u7oMbeXkLBsnLoDMlnRIt8i -O /content/runningpose/runningpose/checkpoint/runningpose_100.bin
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1bEPUXcjW7u7oMbeXkLBsnLoDMlnRIt8i
# From (redirected): https://drive.google.com/uc?id=1bEPUXcjW7u7oMbeXkLBsnLoDMlnRIt8i&confirm=t&uuid=0212c73c-31c7-4275-8f85-7df8fc73edd8
# To: /content/runningpose/runningpose/checkpoint/runningpose_100.bin
# 100% 271M/271M [00:03<00:00, 77.1MB/s]

# %%
# Copy to data directory
# !cp /content/drive/MyDrive/running_dataset/video1.mp4 /content/runningpose/runningpose/data

# %%
# Create a custom dataset
# %cd /content/runningpose/runningpose/data
# !python /content/runningpose/runningpose/data/prepare_data_2d_custom.py -i /content/runningpose/runningpose/data/video1.mp4 -o myvideos
# Out:
# /content/runningpose/runningpose/data
# Parsing 2D detections from /content/runningpose/runningpose/data/video1.mp4
# Saving...
# Done.

# %%
# !python /content/runningpose/runningpose/run.py -d /content/runningpose/runningpose/data/data_2d_custom_myvideos.npz -k myvideos -arc 3,3,3,3,3 -c checkpoint --evaluate runningpose_100.bin --render --viz-subject input_video.mp4 --viz-action custom --viz-camera 0 --viz-video /path/to/input_video.mp4 --viz-output output.mp4 --viz-size 6
# Out:
# Namespace(dataset='/content/runningpose/runningpose/data/data_2d_custom_myvideos.npz', keypoints='myvideos', subjects_train='S1,S5,S6,S7,S8', subjects_test='S9,S11', subjects_unlabeled='', actions='*', checkpoint='checkpoint', checkpoint_frequency=10, resume='', evaluate='runningpose_100.bin', render=True, by_subject=False, export_training_curves=False, stride=1, epochs=60, batch_size=1024, dropout=0.25, learning_rate=0.001, lr_decay=0.95, data_augmentation=True, test_time_augmentation=True, architecture='3,3,3,3,3', causal=False, channels=1024, subset=1, downsample=1, warmup=1, no_eval=False, dense=False, disable_optimizations=False, linear_projection=False, bone_length_term=True, no_proj=False, viz_subject='input_video.mp4', viz_action='custom', viz_camera=0, viz_video='/path/to/input_video.mp4', viz_skip=0, viz_output='output.mp4', viz_export=None, viz_bitrate=3000, viz_no_ground_truth=False, viz_limit=-1, viz_downsample=1, viz_size=6)
# Loading dataset...
# ...
